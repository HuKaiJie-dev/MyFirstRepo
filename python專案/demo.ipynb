# %% [markdown]
# <a href="https://colab.research.google.com/github/HuKaiJie-dev/MyFirstRepo/blob/main/python%E5%B0%88%E6%A1%88/demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 這一個`sin圖表`的範例

# %%
# prompt: create a sin plot

import matplotlib.pyplot as plt
import numpy as np

# Generate x values from 0 to 2π
x = np.linspace(0, 2 * np.pi, 100)

# Calculate corresponding y values for sin(x)
y = np.sin(x)

# Create the plot
plt.plot(x, y)

# Add labels and title
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.title("Sine Wave")

# Display the plot
plt.show()

# %%
# prompt: create a cos plot

import matplotlib.pyplot as plt
import numpy as np

# Generate x values from 0 to 2π
x = np.linspace(0, 2 * np.pi, 100)

# Calculate corresponding y values for sin(x)
y = np.cos(x)

# Create the plot
plt.plot(x, y)

# Add labels and title
plt.xlabel("x")
plt.ylabel("cos(x)")
plt.title("Cosine Wave")

# Display the plot
plt.show()

# %%
# prompt: create a tan plot

import matplotlib.pyplot as plt
import numpy as np

# Generate x values from 0 to 2π
x = np.linspace(0, 2 * np.pi, 100)

# Calculate corresponding y values for sin(x)
y = np.tan(x)

# Create the plot
plt.plot(x, y)

# Add labels and title
plt.xlabel("x")
plt.ylabel("tan(x)")
plt.title("tan Wave")

# Display the plot
plt.show()

# %%
# prompt: create a sin, cos plot

import matplotlib.pyplot as plt
import numpy as np

# Generate x values from 0 to 2π
x = np.linspace(0, 2 * np.pi, 100)

# Calculate corresponding y values for sin(x)
y = np.sin(x)
y2 = np.cos(x)

# Create the plot
plt.plot(x, y, "-")
plt.plot(x, y2, ".")

# Add labels and title
plt.xlabel("x")
plt.ylabel("-")
plt.title("Wave")

# Display the plot
plt.show()
